# %%
notebooks=[
    "/Workspace/Users/.../databricks_bike_lakehouse/bike_lakehouse/gold/gold_dim_customers",
    "/Workspace/Users/.../databricks_bike_lakehouse/bike_lakehouse/gold/gold_dim_products",
    "/Workspace/Users/.../databricks_bike_lakehouse/bike_lakehouse/gold/gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    result=dbutils.notebook.run(nb, timeout_seconds=0)
    print(f"Finished {nb}, Result: {result}")
