# %%
df = spark.table("gold.fact_sales")

df.write \
.format("jdbc") \
.option("url","jdbc:postgresql://host:5432/postgres") \
.option("dbtable","fact_sales") \
.option("user","postgres") \
.option("password","postgres") \
.mode("append") \
.save()
