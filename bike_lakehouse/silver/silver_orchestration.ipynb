# %%
notebooks=["/Workspace/Users/.../databricks_bike_lakehouse/bike_lakehouse/silver/crm/silver_crm_cust_info",
           "/Workspace/Users/.../databricks_bike_lakehouse/bike_lakehouse/silver/crm/silver_crm_prd_info",
           "/Workspace/Users/.../databricks_bike_lakehouse/bike_lakehouse/silver/crm/silver_crm_sales_details",
           "/Workspace/Users/.../databricks_bike_lakehouse/bike_lakehouse/silver/erp/silver_erp_cust_az12",
           "/Workspace/Users/.../databricks_bike_lakehouse/bike_lakehouse/silver/erp/silver_erp_loc_a101",
            "/Workspace/Users/.../databricks_bike_lakehouse/bike_lakehouse/silver/erp/silver_erp_px_cat_g1v2"
            ]

for nb in notebooks:
  print(f"Running {nb}")
  result=dbutils.notebook.run(nb, timeout_seconds=0)
  print(f"Finished {nb}, Result: {result}")
