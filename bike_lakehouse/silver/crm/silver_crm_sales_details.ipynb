# %% [markdown]
# # Initialization

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StringType, DateType , IntegerType
from pyspark.sql.functions import trim, col

# %% [markdown]
# # Read Bronze table

# %%
df=spark.table("bronze.crm_sales_details")

# %%
df.display()

# %%
df.dtypes

# %% [markdown]
# # Silver Transformations

# %% [markdown]
# ## Checking if any column has NULLs
# ##

# %%
# count the nulls in each column

null_stats = (
    df.select([
        F.count(F.when(F.col(c).isNull(), c)).alias(c)
        for c in df.columns
    ])
)

display(null_stats)

# %% [markdown]
# ## Trimming

# %%
for field in df.schema.fields:
  if field.dataType == StringType():
    df = df.withColumn(field.name, trim(col(field.name)))
df.display()

# %%
# check if date columns have 0s
cols = ["sls_due_dt", "sls_order_dt", "sls_ship_dt"]
zero_stats = (
    df.select([
        F.count(F.when(F.col(c)==0, c)).alias(c)
        for c in cols
    ])
)

display(zero_stats)

# %% [markdown]
# ## Cleaning Dates

# %%
cols = ["sls_due_dt", "sls_order_dt", "sls_ship_dt"]

for c in cols:
  df = df.withColumn(c, 
                     F.when(
                         (col(c)==0) | (F.length(col(c))!=8), None) 
                     .otherwise(F.to_date(col(c).cast("string"), "yyyyMMdd")))

# %%
df.display()

# %%
df.dtypes

# %% [markdown]
# ## Sales and Price Corrections

# %%
from functools import reduce
#check which rows are NULL

condition = reduce(lambda a, b: a | b, (F.col(c).isNull()for c in df.columns))
df.filter(condition).display()

# %%
df = (
    df
    .withColumn(
        "sls_price",
        F.when(
            (col("sls_price").isNull()) | (col("sls_price") <= 0),
            F.when(
                col("sls_quantity") != 0,
                col("sls_sales") / col("sls_quantity")
            ).otherwise(None)
        ).otherwise(col("sls_price"))
    )
)

# %% [markdown]
# ### Sales=quantity*price

# %%
# count the nulls in each column

null_stats = (
    df.select([
        F.count(F.when(F.col(c).isNull(), c)).alias(c)
        for c in df.columns
    ])
)

display(null_stats)

# %%
df.filter(F.col("sls_sales").isNull()).display()

# %%
df.filter(F.col("sls_sales")<0).display()

# %%
df = df.withColumn(
    "sls_sales",
    F.when(
        col("sls_sales").isNull() | (col("sls_sales") < 0),
        col("sls_quantity") * col("sls_price")
    ).otherwise(col("sls_sales"))

)

# %%
df.filter(F.col("sls_sales")<0).display()

# %%
null_stats = (
    df.select([
        F.count(F.when(F.col(c).isNull(), c)).alias(c)
        for c in df.columns
    ])
)

display(null_stats)

# %% [markdown]
# ## Renaming the Columns

# %%
RENAME_MAP = {
    "sls_ord_num": "order_number",
    "sls_prd_key": "product_number",
    "sls_cust_id": "customer_id",
    "sls_order_dt": "order_date",
    "sls_ship_dt": "ship_date",
    "sls_due_dt": "due_date",
    "sls_sales": "sales_amount",
    "sls_quantity": "quantity",
    "sls_price": "price"
}

# %%
for old,new in RENAME_MAP.items():
  df = df.withColumnRenamed(old,new)
df.limit(5).display()

# %% [markdown]
# ## Sanity checks of dataframe

# %%
# check NULLs in renamed columns

null_stats = (
    df.select([
        F.count(F.when(F.col(c).isNull(), c)).alias(c)
        for c in df.columns
    ])
)

display(null_stats)

# %%
df.limit(10).display()

# %%
df.dtypes

# %%
# Run Data Quality Checks BEFORE writing to Silver

assert df.count() > 0 , \
    "FAILED: Sales table is empty"
assert df.filter("order_number IS NULL").count() == 0, \
    "FAILED: Sales table has NULLs in order_number"
assert df.count() == df.dropDuplicates(["order_number", "product_number"]).count(), \
    "FAILED: Sales table has duplicate order_numbers"
assert df.filter("sales_amount < 0").count() == 0 , \
    "FAILED: Sales table has negative sales_amounts"

# %% [markdown]
# # Write Into Silver Table

# %%
df.write.mode("overwrite").format("delta").saveAsTable("workspace.silver.crm_sales")

# %% [markdown]
# ## Sanity checks of Silver table

# %%
# %sql
SELECT * FROM workspace.silver.crm_sales LIMIT 10

# %%
# %sql
SELECT * FROM workspace.silver.crm_sales 
WHERE order_date>ship_date OR order_date>due_date
